# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import itertools # 조합을 사용하기 위해 itertools를 import

def solution(number):
    answer = 0
    li = list(itertools.combinations(number,3)) # nC3
    for i in range(len(li)):
        if (li[i][0]+li[i][1]+li[i][2]) == 0:
            answer += 1
    return answer
