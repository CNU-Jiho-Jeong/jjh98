# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 풀이

# %%
import sys
input = sys.stdin.readline

a = 0

Jinho = input()
N = int(input())

for i in range(N):
    friend = input()
    if friend == Jinho:
        a += 1
print(a)
