# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 풀이

# %%
A, B = input().split()
A = int(A)
B = int(B)

while(1):
    B = A+B
    if B>=5:
        print("yt")
        break
    A = A + B
    if A>=5:
        print("yj")
        break
