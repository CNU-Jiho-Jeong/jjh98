# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 풀이

# %%
N = int(input())
sottuk = input()

for i in range(N):
    if sottuk.count("s") == sottuk.count("t"):
        print(sottuk)
        break
    else:
        sottuk = sottuk[1:] # 왼쪽 문자 하나를 간단히 잘라내는 방법
